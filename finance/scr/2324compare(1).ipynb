# %%
import pandas as pd

def analyze_financial_metrics(singtel_file, industry_file):
    # 读取数据
    singtel_financial_data = pd.read_csv('/Users/jessieb/Desktop/Singtel_financial_data.csv')
    financial_infotech_data = pd.read_csv('/Users/jessieb/Desktop/financial mean.csv')

    # 清理数据，确保列名一致，年份为数值类型
    singtel_financial_data.columns = singtel_financial_data.columns.str.strip()
    singtel_financial_data['Year'] = pd.to_numeric(singtel_financial_data['Year'], errors='coerce')

    # 筛选2023和2024年的数据
    metrics_comparison = singtel_financial_data[singtel_financial_data['Year'].isin([2023, 2024])][
        ['Year', 'Return on Equity (ROE)', 'Return on Assets (ROA)', 'Operating Margin', 'Net Profit Margin', 
         'Diluted Normalised EPS', 'Current Ratio', 'Asset Turnover', 'Quick Ratio']
    ]

    # 提取2024年的industry average
    industry_metrics = financial_infotech_data[financial_infotech_data['Year'] == 2024].iloc[0]

    # 提取2023年和2024年的指标数据
    year_metrics = metrics_comparison.set_index('Year').T

    # 结果生成函数
    def generate_result(metric, value_23, value_24, industry_value):
        trend_result = f"The company's {metric} is {'increasing' if value_24 > value_23 else 'decreasing'}, indicating "
        if metric == 'Return on Equity (ROE)':
            trend_result += "profitability changes per dollar of shareholders' money."
        elif metric == 'Return on Assets (ROA)':
            trend_result += "efficiency in utilizing its assets."
        elif metric == 'Operating Margin':
            trend_result += "profitability from its core business relative to revenue."
        elif metric == 'Net Profit Margin':
            trend_result += "effectiveness in converting revenue to profit."
        elif metric == 'Diluted Normalised EPS':
            trend_result += "changes in shareholder payouts."
        elif metric == 'Current Ratio':
            trend_result += "changes in short-term liquidity."
        elif metric == 'Quick Ratio':
            trend_result += "changes in immediate financial stability."
        elif metric == 'Asset Turnover':
            trend_result += "efficiency in using its assets to generate revenue."
        
        industry_comparison = f" The company's {metric} is {'above' if value_24 > industry_value else 'below'} the industry average."
        return trend_result + industry_comparison

    # 存储结果
    results = []
    for metric in [
        'Return on Equity (ROE)', 'Return on Assets (ROA)', 'Operating Margin', 
        'Net Profit Margin', 'Diluted Normalised EPS', 'Current Ratio', 
        'Asset Turnover', 'Quick Ratio'
    ]:
        value_23 = year_metrics.loc[metric, 2023]
        value_24 = year_metrics.loc[metric, 2024]
        industry_value = industry_metrics[metric]
        results.append(generate_result(metric, value_23, value_24, industry_value))
    
    return results

# 使用示例
# results = analyze_financial_metrics(
#     '/Users/jessieb/Desktop/Singtel_financial_data.csv',
#     '/Users/jessieb/Desktop/financial mean.csv'
# )

# 输出结果
for result in results:
    print(result)
# Out:
# The company's Return on Equity (ROE) is decreasing, indicating profitability changes per dollar of shareholders' money. The company's Return on Equity (ROE) is above the industry average.
# The company's Return on Assets (ROA) is decreasing, indicating efficiency in utilizing its assets. The company's Return on Assets (ROA) is above the industry average.
# The company's Operating Margin is decreasing, indicating profitability from its core business relative to revenue. The company's Operating Margin is above the industry average.
# The company's Net Profit Margin is decreasing, indicating effectiveness in converting revenue to profit. The company's Net Profit Margin is above the industry average.
# The company's Diluted Normalised EPS is decreasing, indicating changes in shareholder payouts. The company's Diluted Normalised EPS is above the industry average.
# The company's Current Ratio is increasing, indicating changes in short-term liquidity. The company's Current Ratio is below the industry average.
# The company's Asset Turnover is decreasing, indicating efficiency in using its assets to generate revenue. The company's Asset Turnover is below the industry average.
# The company's Quick Ratio is increasing, indicating changes in immediate financial stability. The company's Quick Ratio is below the industry average.

# %%
import pandas as pd

# 读取数据
financial_data = pd.read_csv('../../data/financial_data.csv')
singtel_financial_data = financial_data[financial_data['Company'] == 'Singtel']

financial_infotech_data = pd.read_csv('../../data/financial_mean.csv')

# 清理数据，确保列名一致，年份为数值类型
singtel_financial_data.columns = singtel_financial_data.columns.str.strip()
singtel_financial_data['Year'] = pd.to_numeric(singtel_financial_data['Year'], errors='coerce')

# 筛选2023和2024年的数据
metrics_comparison = singtel_financial_data[singtel_financial_data['Year'].isin([2023, 2024])][
    ['Year', 'Return on Equity (ROE)', 'Return on Assets (ROA)', 'Operating Margin', 'Net Profit Margin', 
        'Diluted Normalised EPS', 'Current Ratio', 'Asset Turnover', 'Quick Ratio']
]

# 提取2024年的industry average
industry_metrics = financial_infotech_data[financial_infotech_data['Year'] == 2024].iloc[0]

# 提取2023年和2024年的指标数据
year_metrics = metrics_comparison.set_index('Year').T

# 结果生成函数
def generate_result(metric, value_23, value_24, industry_value):
    trend_result = f"The company's {metric} is {'increasing' if value_24 > value_23 else 'decreasing'}, indicating "
    if metric == 'Return on Equity (ROE)':
        trend_result += "profitability changes per dollar of shareholders' money."
    elif metric == 'Return on Assets (ROA)':
        trend_result += "efficiency in utilizing its assets."
    elif metric == 'Operating Margin':
        trend_result += "profitability from its core business relative to revenue."
    elif metric == 'Net Profit Margin':
        trend_result += "effectiveness in converting revenue to profit."
    elif metric == 'Diluted Normalised EPS':
        trend_result += "changes in shareholder payouts."
    elif metric == 'Current Ratio':
        trend_result += "changes in short-term liquidity."
    elif metric == 'Quick Ratio':
        trend_result += "changes in immediate financial stability."
    elif metric == 'Asset Turnover':
        trend_result += "efficiency in using its assets to generate revenue."
    
    industry_comparison = f" The company's {metric} is {'above' if value_24 > industry_value else 'below'} the industry average."
    return trend_result + industry_comparison

# 存储结果
results = []
for metric in [
    'Return on Equity (ROE)', 'Return on Assets (ROA)', 'Operating Margin', 
    'Net Profit Margin', 'Diluted Normalised EPS', 'Current Ratio', 
    'Asset Turnover', 'Quick Ratio']:
    
    value_23 = year_metrics.loc[metric, 2023]
    value_24 = year_metrics.loc[metric, 2024]
    industry_value = industry_metrics[metric]
    results.append(generate_result(metric, value_23, value_24, industry_value))
# Out:
# /var/folders/c9/4kphgljx4_sbt47w_56k4s940000gn/T/ipykernel_84815/1964790931.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   singtel_financial_data['Year'] = pd.to_numeric(singtel_financial_data['Year'], errors='coerce')

# %%
for result in results:
    print(result)
# Out:
# The company's Return on Equity (ROE) is decreasing, indicating profitability changes per dollar of shareholders' money. The company's Return on Equity (ROE) is above the industry average.
# The company's Return on Assets (ROA) is decreasing, indicating efficiency in utilizing its assets. The company's Return on Assets (ROA) is above the industry average.
# The company's Operating Margin is decreasing, indicating profitability from its core business relative to revenue. The company's Operating Margin is above the industry average.
# The company's Net Profit Margin is decreasing, indicating effectiveness in converting revenue to profit. The company's Net Profit Margin is above the industry average.
# The company's Diluted Normalised EPS is decreasing, indicating changes in shareholder payouts. The company's Diluted Normalised EPS is above the industry average.
# The company's Current Ratio is increasing, indicating changes in short-term liquidity. The company's Current Ratio is below the industry average.
# The company's Asset Turnover is decreasing, indicating efficiency in using its assets to generate revenue. The company's Asset Turnover is below the industry average.
# The company's Quick Ratio is increasing, indicating changes in immediate financial stability. The company's Quick Ratio is below the industry average.
